# %%
import os
from IPython.display import Markdown, display
from dotenv import load_dotenv
from openai import OpenAI

# %%
load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
if not api_key:
    raise RuntimeError("OPENAI_API_KEY is not set in the environment")
print("Hello from ai-projects!")
print(f"OpenAI API key loaded: {api_key[:8]}...")
# Out:
# Hello from ai-projects!
# OpenAI API key loaded: sk-proj-...

# %%
message='Hello GPT! This is my first ever message to you! Hi!'
messages = [{"role": "user", "content": message}]
print(messages)
# Out:
# [{'role': 'user', 'content': 'Hello GPT! This is my first ever message to you! Hi!'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(model='gpt-5-nano', messages=messages)
response.choices[0].message.content
# Out:
# 'Nice to meet you! I’m here to help with questions, brainstorm ideas, practice skills, or just chat. What would you like to do first? If you’re not sure, tell me a bit about your interests and I can suggest some ideas. Examples: quick explanations of topics, writing help, planning a project, learning something new, or practicing a language.'
